# %%
import pandas as pd
import numpy as np
pd.set_option("display.max_rows", 20, "display.max_columns", None)
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import scipy.stats as stats
import math
import warnings
warnings.filterwarnings('ignore')
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('fifa21_trainning.csv')
data.head()
# Out:
#    Unnamed: 0      ID           Name  Age  Nationality  \
# 0        1954  184383      A. Pasche   26  Switzerland
# 1        2225  188044  Alan Carvalho   30     China PR
# 2        1959  184431    S. Giovinco   33        Italy
# 3        9815  233796       J. Evans   22        Wales
# 4       10074  234799     Y. Demoncy   23       France
#
#                          Club   BP  Position  \
# 0           FC Lausanne-Sport   CM    CM CDM
# 1     Beijing Sinobo Guoan FC   ST  ST LW LM
# 2                    Al Hilal  CAM    CAM CF
# 3                Swansea City  CDM    CDM CM
# 4  US Orléans Loiret Football  CDM    CDM CM
#
#                                 Team & Contract Height  Weight   foot  Growth  \
# 0                 FC Lausanne-Sport 2015 ~ 2020   5'9"  161lbs  Right       1
# 1  Beijing Sinobo Guoan FC Dec 31, 2020 On Loan   6'0"  159lbs  Right       0
# 2                          Al Hilal 2019 ~ 2022   5'4"  134lbs  Right       0
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Nationality', 'Club', 'BP',
#        'Position', 'Team & Contract', 'Height',
#        ...
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'GK', 'OVA'],
#       dtype='object', length=102)

# %%
data.isna().sum()
# Out:
# Unnamed: 0     0
# ID             0
# Name           0
# Age            0
# Nationality    0
#               ..
# CB             0
# RCB            0
# RB             0
# GK             0
# OVA            0
# Length: 102, dtype: int64

# %%
data.isnull().sum()
# Out:
# Unnamed: 0     0
# ID             0
# Name           0
# Age            0
# Nationality    0
#               ..
# CB             0
# RCB            0
# RB             0
# GK             0
# OVA            0
# Length: 102, dtype: int64

# %%
def Wage(amount): 
    if (amount[-1]=="M"):
        return float(amount[1:-1])*1000000 
    elif(amount[-1]=="K"):
        return float(amount[1:-1])*1000
    else:
        return float(amount[1:])

    

print(Wage("€1M"))
# Out:
# 1000000.0

# %%
def clean_wage(data):
   # data = data.copy()
    cols_to_clean = ['Wage','Value','Release Clause']
    for col in cols_to_clean:
        data[col] = data[col].apply(lambda x: Wage(x))
        #data[col]=map(Wage, data[col])
    return data

# print(data)

# %%
def clean_dataset(df):
    df = clean_wage(df)
   # df = clean_weight(df)
    return df


#print(df)

# %%
data = clean_dataset(data)
data
# Out:
#        Unnamed: 0      ID           Name  Age  Nationality  \
# 0            1954  184383      A. Pasche   26  Switzerland
# 1            2225  188044  Alan Carvalho   30     China PR
# 2            1959  184431    S. Giovinco   33        Italy
# 3            9815  233796       J. Evans   22        Wales
# 4           10074  234799     Y. Demoncy   23       France
# ...           ...     ...            ...  ...          ...
# 13695       11284  239074          S. Aw   21      Senegal
# 13696       11964  241223        S. Mogi   21        Japan
# 13697        5390  210930     Carles Gil   27        Spain
# 13698         860  162993       J. Perch   34      England
# 13699       15795  254882  A. Oeynhausen   18      Germany
#
#                              Club   BP   Position  \
# 0               FC Lausanne-Sport   CM     CM CDM
# 1         Beijing Sinobo Guoan FC   ST   ST LW LM
# 2                        Al Hilal  CAM     CAM CF
# 3                    Swansea City  CDM     CDM CM
# ...

# %%
iqr = np.percentile(data['OVA'],75) - np.percentile(data['OVA'],25)
upper_limit = np.percentile(data['OVA'],75) + 1.5*iqr
lower_limit = np.percentile(data['OVA'],25) - 1.5*iqr

# %%
plt.scatter(x=data['Value'], y=data['OVA'])
plt.show()

# %%
data['OVA'].hist()
plt.show()

# %%
sns.distplot(data['OVA'], bins=50)
plt.show()

# %%
data[['OVA']].boxplot()
plt.show()

# %%
from sklearn.preprocessing import Normalizer

# %%
x=data['Wage']
y=data['OVA']
stats.pearsonr(x, y) # gives correlation coefficient and the p value
# Out:
# (0.5867492669947852, 0.0)

# %%
lm = linear_model.LinearRegression()

# We "train" our linear model based on the data available on X_train and y_train
model = lm.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-9d55780645cd> in <module>
#       2
#       3 # We "train" our linear model based on the data available on X_train and y_train
# ----> 4 model = lm.fit(X_train,y_train)
#
# NameError: name 'X_train' is not defined

# %%
# fit the normalizer
transformer = Normalizer().fit(X_num)

# transform our data
x_normalized = transformer.transform(X_num)
print(x_normalized.shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-9b1a49b5a16e> in <module>
#       1 # We fit the normalizer
# ----> 2 transformer = Normalizer().fit(X_num)
#       3
#       4 # We transform our data
#       5 x_normalized = transformer.transform(X_num)
#
# c:\users\vtarv\appdata\local\programs\python\python39\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y)
#    2021             Fitted transformer.
#    2022         """
# -> 2023         self._validate_data(X, accept_sparse='csr')
#    2024         return self
#    2025
#
# c:\users\vtarv\appdata\local\programs\python\python39\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     419             out = X
#     420         elif isinstance(y, str) and y == 'no_validation':
# --> 421             X = check_array(X, **check_params)
# ...

# %%
predictions = lm.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-d148e38fd152> in <module>
# ----> 1 predictions  = lm.predict(X_test)
#
# NameError: name 'X_test' is not defined

# %%
lm = linear_model.LinearRegression()

# We "train" our linear model based on the data available on X_train and y_train
model = lm.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-9d55780645cd> in <module>
#       2
#       3 # We "train" our linear model based on the data available on X_train and y_train
# ----> 4 model = lm.fit(X_train,y_train)
#
# NameError: name 'X_train' is not defined
